# %%
# import fitz

# pdf_path = "NYstandards.pdf"  # Replace with your PDF file path

# def extract_bold_sentences(pdf_path):
#     doc = fitz.open(pdf_path)
#     bold_sentences = []
#     current_sentence = []

#     for page in doc:
#         text_instances = page.get_text("dict")  # Extract text in dictionary format

#         for block in text_instances.get("blocks", []):
#             for line in block.get("lines", []):
#                 for span in line.get("spans", []):
#                     font = span["font"]  # Get font name
#                     text = span["text"].strip()  # Extract text and strip spaces

#                     # Check if font contains 'Bold'
#                     if "Bold" in font:
#                         current_sentence.append(text)  # Add to current sentence
#                     else:
#                         if current_sentence:
#                             sentence = " ".join(current_sentence).strip()  # Join and strip spaces
#                             bold_sentences.append(sentence)
#                             current_sentence = []  # Reset for next sentence

#     # Capture any remaining sentence
#     if current_sentence:
#         sentence = " ".join(current_sentence).strip()
#         bold_sentences.append(sentence)

#     return bold_sentences

# # Run extraction
# bold_sentences = extract_bold_sentences(pdf_path)

# # Print results
# for i, sentence in enumerate(bold_sentences):
#     print(f"Bold Sentence {i+1}: {sentence}")

# %%
import fitz  # PyMuPDF

pdf_path = "NYstandards.pdf"  # Replace with your actual PDF path

def extract_bold_sentences(pdf_path):
    doc = fitz.open(pdf_path)
    bold_sentences = []
    temp_sentence = ""
    previous_block_bbox = None  # Track previous block for table detection

    for page in doc:
        text_instances = page.get_text("dict")  # Get text in dictionary format

        for block in text_instances.get("blocks", []):
            if not isinstance(block, dict):  # Skip invalid blocks
                continue
            
            current_block_bbox = block.get("bbox")  # Get bounding box for table separation
            in_table = previous_block_bbox == current_block_bbox  # Check if block is part of a table
            previous_block_bbox = current_block_bbox

            for line in block.get("lines", []):
                for span in line.get("spans", []):
                    font = span.get("font", "")  # Get font name
                    text = span.get("text", "").strip()  # Extract text

                    # Check if the font is bold
                    if "Bold" in font:
                        if in_table:
                            # If text is inside a table, save separately
                            if temp_sentence:
                                bold_sentences.append(temp_sentence)
                                temp_sentence = ""
                            bold_sentences.append(text)
                        else:
                            # Merge multi-line bold text
                            if temp_sentence:
                                temp_sentence += " " + text
                            else:
                                temp_sentence = text
                    else:
                        # If normal text appears, finalize the bold sentence
                        if temp_sentence:
                            bold_sentences.append(temp_sentence)
                            temp_sentence = ""

            # Append any remaining bold text at the end of the block
            if temp_sentence:
                bold_sentences.append(temp_sentence)
                temp_sentence = ""

    return bold_sentences

# Extract bolded sentences
bold_sentences = extract_bold_sentences(pdf_path)

# Display results
for i, sentence in enumerate(bold_sentences):
    print(f"{i+1}. {sentence}")
# Out:
# 1. New York State Department of Health  Wadsworth Center  Clinical Laboratory Evaluation Program
# 2. TABLE OF CONTENTS
# 3. DEFINITIONS  Acceptability criteria
# 4. Alternative assessment
# 5. Amended report
# 6. Annual
# 7. Assistant director(s)
# 8. Auditing
# 9. Autorelease
# 10. Autoverification
# 11. Blood bank
# 12. .
# 13. Category
# 14. Certificate of qualification (CQ)
# 15. DEFINITIONS
# 16. Clinical laboratory
# 17. Corrected report
# 18. Corrective action
# 19. Data integrity
# 20. Delegate
# 21. Director (Clinical Laboratory Director)
# 22. Document control
Regulatory authority: 10 NYCRR subdivision 58-1.2(c)
# 255. Laboratory Information Systems Standard of Practice 5 (LIS S5): Calculation and Algorithm Verification
# 256. Laboratory Information Systems
# 257. Standard Guidance
# 258. Regulatory authority: 10 NYCRR subdivision 58-1.2(c)
# 259. Laboratory Information Systems Standard of Practice 6 (LIS S6): Systems Failure
# 260. Regulatory authority: 10 NYCRR subdivisions 58-1.2(c) and 58-1.11(c)
# 261. Resource Management
# 262. Resource Management
# 263. Standard
# 264. Guidance
# 265. Resource Management Fundamental Standard of Practice (RM FS)
# 266. Statutory authority: Article 5, Title 5 Public Health Law Sections 575(2) and (3)
# 267. General Resource Management
# 268. General Resource Management Standard of Practice 1 (GRM S1): Continuity of Operations Plan
# 269. Resource Management
# 270. Standard
# 271. Guidance
# 272. Regulatory authority: 10 NYCRR paragraph 19.3(c)(2) and subdivision 58-1.10(g)
# 273. General Resource Management Standard of Practice 2 (GRM S2): Testing Supplies
# 274. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 275. General Resource Management Standard of Practice 3 (GRM S3): Manufacturer Requirements
# 276. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 277. Resource Management
# 278. Standard
# 279. Guidance
# 280. General Resource Management Standard of Practice 4 (GRM S4): Verification – General Requirement
# 281. Regulatory authority: 10 NYCRR subdivision 58-1.10(g) and section 58-1.6
# 282. Resource Management
# 283. Standard
# 284. Guidance
# 285. General Resource Management Standard of Practice 5 (GRM S5): Support Material Verification
# 286. Regulatory authority: 10 NYCRR section 58-1.6
# 287. General Resource Management Standard of Practice 6 (GRM S6): Expired Supplies
# 288. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 289. Resource Management
# 290. Standard
# 291. Guidance
# 292. General Resource Management Standard of Practice 7 (GRM S7): Computer Systems Security
# 293. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 294. Laboratory Equipment and Instrument
# 295. Laboratory Equipment and Instrument Standard of Practice 1 (LEI S1): Hardware and Software Settings
# 296. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 297. Laboratory Equipment and Instrument Standard of Practice 2 (LEI S2): Instrument and Equipment Records
# 298. Resource Management
# 299. Standard
# 300. Guidance
# 301. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 302. Laboratory Equipment and Instrument Standard of Practice 3 (LEI S3): Function Checks and Performance Verification of Instruments, Equipment and Test Systems
# 303. Resource Management
# 304. Standard
# 305. Guidance
# 306. Regulatory authority: 10 NYCRR section 58-1.6
# 307. Laboratory Equipment and Instrument Standard of Practice 4 (LEI S4): Performance Verification After Relocation
# 308. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 309. Laboratory Equipment and Instrument Standard of Practice 5 (LEI S5): Instruction for Maintenance and Preventive Maintenance
# 310. Regulatory authority: 10 NYCRR section 58-1.6
# 311. Laboratory Equipment and Instrument Standard of Practice 6 (LEI S6): Maintenance and Preventive Maintenance Records
# 312. Resource Management
# 313. Standard
# 314. Guidance
# 315. Regulatory authority: 10 NYCRR section 58-1.6
# 316. Laboratory Equipment and Instrument Standard of Practice 7 (LEI S7): Managing Defective Equipment and Instruments
# 317. Regulatory authority: 10 NYCRR section 58-1.6
# 318. Resource Management
# 319. Standard
# 320. Guidance
# 321. Laboratory Equipment and Instrument Standard of Practice 8 (LEI S8): Carbon Dioxide Incubators
# 322. Regulatory authority: 10 NYCRR section 58-1.6
# 323. Laboratory Equipment and Instrument Standard of Practice 9 (LEI S9): Thermal Cyclers and Polymerase Chain Reaction
# 324. Regulatory authority: 10 NYCRR section 58-1.6
# 325. Resource Management
# 326. Standard
# 327. Guidance
# 328. Reagents and Media
# 329. Reagent and Media Standard of Practice 1 (RGM S1): Reagent and Media Records
# 330. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 331. Reagents and Media Standard of Practice 2 (RGM S2): Verification of Reagents and Media – Control Procedures
# 332. Resource Management
# 333. Standard
# 334. Guidance
# 335. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 336. Resource Management
# 337. Standard
# 338. Guidance
# 339. Reagents and Media Standard of Practice 3 (RGM S3): Labeling
# 340. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 341. Reagents and Media Standard of Practice 4 (RGM S4): Kit Components
# 342. Resource Management
# 343. Standard
# 344. Guidance
# 345. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 346. Reagents and Media Standard of Practice 5 (RGM S5): Reagent and Media Storage
# 347. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 348. Document Control
# 349. Document Control
# 350. Standard Guidance
# 351. Document Control Fundamental Standard of Practice (DC FS)
# 352. Statutory authority: Article 5, Title 5 Public Health Law Sections 575(2) and (3)
# 353. Document Control Standard of Practice 1 (DC S1): Availability
# 354. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 355. Document Control
# 356. Standard Guidance
# 357. Document Control Standard of Practice 2 (DC S2): Compliance
# 358. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 359. Document Control Standard of Practice 3 (DC S3): Manufacturer Instruction Manuals
# 360. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 361. Document Control Standard of Practice 4 (DC S4): Procedure Excerpts
# 362. Document Control
# 363. Standard Guidance
# 364. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 365. Document Control Standard of Practice 5 (DC S5): Director Approval
# 366. Regulatory authority: 10 NYCRR subdivisions 58-1.2(c) and 58-1.10(g)
# 367. Document Control
# 368. Standard Guidance
# 369. Document Control Standard of Practice 6 (DC S6): Controlled Document Archival
# 370. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 371. Pre-Analytic Systems
# 372. Pre-Analytic Systems
# 373. Standard Guidance
# 374. Pre-Analytic Systems Fundamental Standard of Practice (PRS FS)
# 375. Statutory authority: Article 5, Title 5 Public Health Law Sections 575(2) and (3)
# 376. Test Request
# 377. Test Request Standard of Practice 1 (TR S1): Specimen Testing
# 378. Regulatory authority: 10 NYCRR subdivisions 58-1.7(a) and (b)
# 379. Pre-Analytic Systems
# 380. Standard Guidance
# 381. Test Request Standard of Practice 2 (TR S2): Verbal Test Request
# 382. Regulatory authority: 10 NYCRR paragraph 58-1.7(b)(1)
# 383. Test Request Standard of Practice 3 (TR S3): Test Request Form
# 384. Pre-Analytic Systems
# 385. Standard Guidance
# 386. Regulatory authority: 10 NYCRR section 58-1.10
# 387. Test Request Standard of Practice 4 (TR S4): Urgent Test Request
# 388. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 389. Pre-Analytic Systems
# 390. Standard Guidance
# 391. Specimen Processing
# 392. Specimen Processing Standard of Practice 1 (SP S1): Specimen Submission Instructions
# 393. Pre-Analytic Systems
# 394. Standard Guidance
# 395. Pre-Analytic Systems
# 396. Standard Guidance
# 397. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 398. Specimen Processing Standard of Practice 2 (SP S2): Monitoring Specimen Submissions
# 399. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 400. Specimen Processing Standard of Practice 3 (SP S3): Client Requests for Test Information
# 401. Regulatory authority: 10 NYCRR paragraph 19.3(c)(1) and subdivision 58-1.10(g)
# 402. Pre-Analytic Systems
# 403. Standard Guidance
# 404. Specimen Processing Standard of Practice 4 (SP  S4): Acceptance and Rejection Procedure
# 405. Regulatory authority: 10 NYCRR subdivision 58-1.10(e)
# 406. Specimen Processing Standard of Practice 5 (SP S5): Accession Procedure and Documentation
# 407. Pre-Analytic Systems
# 408. Standard Guidance
# 409. Regulatory authority: 10 NYCRR paragraph 58-1.11(b)(1)
# 410. Pre-Analytic Systems
# 411. Standard Guidance
# 412. Specimen Processing Standard of Practice 6 (SP S6): Specimen Transport
# 413. Regulatory authority: 10 NYCRR subdivision 58-1.10(d)
# 414. Specimen Processing Standard of Practice 7 (SP
# 415. S7): Portion or Aliquot Identification and Integrity
# 416. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 417. Pre-Analytic Systems
# 418. Standard Guidance
# 419. Specimen Processing Standard of Practice 8 (SP S8): Specimen Storage
# 420. Regulatory authority: 10 NYCRR subdivision 58-1.10(g) and paragraph 58-1.11(d)(1)
# 421. Reference and Contract Laboratories
# 422. Reference and Contract Laboratory Standard of Practice 1 (RCL S1): Reference Laboratory Selection and Use
# 423. Regulatory authority: 10 NYCRR subdivisions 58-1.1(b) and 58-1.10(g)
# 424. Pre-Analytic Systems
# 425. Standard Guidance
# 426. Reference and Contract Laboratory Standard of Practice 2 (RCL S2): Registry of Reference and Contract Laboratories
# 427. Regulatory authority: 10 NYCRR subparagraph 58- 1.11(b)(1)(vi)
# 428. Reference and Contract Laboratory Standard of Practice 3 (RCL S3): Performance Assessment of Reference and Contract Laboratories
# 429. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 430. Analytic Systems
# 431. Analytic Systems
# 432. Standard Guidance
# 433. Analytic Systems Fundamental Standard of Practice (AS FS)
# 434. Statutory authority: Article 5, Title 5 Public Health Law Sections 575(2) and (3)
# 435. Test Procedure Content
# 436. Test Procedure Content Standard of Practice 1 (TPC S1): Test Procedure Content
# 437. Analytic Systems
# 438. Standard Guidance
# 439. Analytic Systems
# 440. Standard Guidance
# 441. Analytic Systems
# 442. Standard Guidance
# 443. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 444. Test Procedure Content Standard of Practice 2 (TPC S2): Test Procedures for Unidirectional Workflow
# 445. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 446. Analytic Systems
# 447. Standard Guidance
# 448. Test Performance Specifications
# 449. Test Performance Specification Standard of Practice 1 (TPS S1): Manufacturer Instructions
# 450. verify
# 451. establish
# 452. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 453. Test Performance Specification Standard of Practice 2 (TPS S2): Laboratory Developed Tests
# 454. Analytic Systems
# 455. Standard Guidance
# 456. establish
# 457. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 458. Test Performance Specification Standard of Practice 3 (TPS S3): Documentation
# 459. Analytic Systems
# 460. Standard Guidance
# 461. Regulatory authority: 10 NYCRR subdivision 58-1.11(c)(3)
# 462. Test Performance Specification Standard of Practice 4 (TPS S4): On-site Performance Specification Requirements
# 463. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 464. Test Performance Specification Standard of Practice 5 (TPS S5): Comparability of Test Results
# 465. Analytic Systems
# 466. Standard Guidance
# 467. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 468. Calibration and Calibration Verification
# 469. Calibration Standard of Practice 1 (CAL S1): Calibration Process and Documentation
# 470. Analytic Systems
# 471. Standard Guidance
# 472. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 473. Calibration Standard of Practice 2 (CAL S2):  Periodic Calibration Verification
# 474. Analytic Systems
# 475. Standard Guidance
# 476. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 477. Quality Control
# 478. Quality Control Standard of Practice 1 (QC S1): Minimum Quality Control Requirements
# 479. Analytic Systems
# 480. Standard Guidance
# 481. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 482. Analytic Systems
# 483. Standard Guidance
# 484. Quality Control Standard of Practice 2 (QC S2): Individualized Quality Control Risk Assessment
# 485. Analytic Systems
# 486. Standard Guidance
# 487. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 488. Quality Control Standard of Practice 3 (QC S3): Design of an Individualized Quality Control Plan
# 489. Analytic Systems
# 490. Standard Guidance
# 491. Analytic Systems
# 492. Standard Guidance
# 493. Regulatory authority: 10 NYCRR paragraph 19.3(c)(3) and subdivision 58-1.10(g)
# 494. Quality Control Standard of Practice 4 (QC S4): Quality Assessment Plan for Individualized Quality Control Plan
# 495. Analytic Systems
# 496. Standard Guidance
# 497. Regulatory authority: 10 NYCRR paragraph 19.3(c)(3) and subdivision 58-1.10(g)
# 498. Quality Control Standard of Practice 5 (QC S5): Control Limits
# 499. Regulatory authority: 10 NYCRR paragraph 19.3(c)(3) and subdivision 58-1.10(g)
# 500. Quality Control Standard of Practice 6 (QC S6): Assayed Value Verification
# 501. Analytic Systems
# 502. Standard Guidance
# 503. Regulatory authority: 10 NYCRR paragraph 19.3(c)(3) and subdivision 58-1.10(g)
# 504. Quality Control Standard of Practice 7 (QC S7): Calibration Material Used as a Quality Control
# 505. Regulatory authority: 10 NYCRR paragraph 19.3(c)(3) and subdivision 58-1.10(g)
# 506. Quality Control Standard of Practice 8 (QC S8): Alternative Means of Quality Control
# 507. Regulatory authority: 10 NYCRR paragraph 19.3(c)(4) and subdivision 58-1.10(g)
# 508. Analytic Systems
# 509. Standard Guidance
# 510. Quality Control Standard of Practice 9 (QC S9): Control Implementation
# 511. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 512. Quality Control Standard of Practice 10 (QC S10): Control Routine Analysis
# 513. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 514. Quality Control Standard of Practice 11 (QC S11): Electrophoresis
# 515. Analytic Systems
# 516. Standard Guidance
# 517. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 518. Quality Control Standard of Practice 12 (QC S12): Thin Layer Chromatography
# 519. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 520. Analytic Systems
# 521. Standard Guidance
# 522. Quality Control Standard of Practice 13 (QC S13): Control Records
# 523. Regulatory authority: 10 NYCRR paragraph 58-1.11(c)(3)
# 524. Quality Control Standard of Practice 14 (QC S14): Control Review
# 525. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 526. Post-Analytic Systems
# 527. Post-Analytic Systems
# 528. Standard Guidance
# 529. Post-Analytic Systems Fundamental Standard of Practice (PAS FS)
# 530. Statutory authority: Article 5, Title 5 Public Health Law Sections 575(2) and (3)
# 531. Result Review
# 532. Result Review Standard of Practice 1 (RR S1): Result Review Criteria
# 533. Post-Analytic Systems
# 534. Standard Guidance
# 535. Regulatory authority: 10 NYCRR paragraph 19.3(c)(4) and subdivision 58-1.10(g)
# 536. Post-Analytic Systems
# 537. Standard Guidance
# 538. Result Review Standard of Practice 2 (RR S2): Acceptable Differences for Replicate Analyses
# 539. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 540. Result Review Standard of Practice 3 (RR S3): Nonconformance Identification
# 541. Post-Analytic Systems
# 542. Standard Guidance
# 543. Regulatory authority: 10 NYCRR paragraph 19.3(c)(4) and subdivision 58-1.10(g)
# 544. Reporting
# 545. Reporting Standard of Practice 1 (REP S1): Authorized Release of Test Results
# 546. Post-Analytic Systems
# 547. Standard Guidance
# 548. Regulatory authority: 10 NYCRR section 58-1.3 and subdivision 58-1.10(b) and (g)
# 549. Reporting Standard of Practice 2 (REP S2): Test Report Content
# 550. Post-Analytic Systems
# 551. Standard Guidance
# 552. Regulatory authority: 10 NYCRR paragraph 58-1.11(b)(2)
# 553. Reporting Standard of Practice 3 (REP S3): Reference and Contract Laboratory Test Reports
# 554. Post-Analytic Systems
# 555. Standard Guidance
# 556. Regulatory authority: 10 NYCRR section 58-1.9
# 557. Reporting Standard of Practice 4 (REP S4): Corrected Reports
# 558. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 559. Post-Analytic Systems
# 560. Standard Guidance
# 561. Reporting Standard of Practice 5 (REP S5): Timeliness
# 562. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 563. Reporting Standard of Practice 6 (REP S6): Alert Value
# 564. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 565. Public Health Reporting
# 566. Public Health Reporting Standard of Practice 1 (PHR S1): Required Public Health Reporting
# 567. Post-Analytic Systems
# 568. Standard Guidance
# 569. Regulatory authority: as noted and 10 NYCRR paragraph 19.3(c)(2)
# 570. Public Health Reporting Standard of Practice 2 (PHR S2): Communicable Disease Confirmation
# 571. Post-Analytic Systems
# 572. Standard Guidance
# 573. Statutory authority: as noted
# 574. Confidentiality
# 575. Confidentiality Standard of Practice 1 (CON S1): Confidentiality Training
# 576. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 577. Confidentiality Standard of Practice 2 (CON S2): Confidentiality Protocol
# 578. Post-Analytic Systems
# 579. Standard Guidance
# 580. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 581. Confidentiality Standard of Practice 3 (CON S3): Controlled Records Access
# 582. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 583. Document and Specimen Retention
# 584. Document and Specimen Retention
# 585. Standard Guidance
# 586. Document and Specimen Retention Fundamental Standard of Practice (DSR FS)
# 587. Statutory authority: Article 5, Title 5 Public Health Law Section 576
# 588. Document and Specimen Retention Standard of Practice 1 (DSR S1): Quality Assurance Records
# 589. Document and Specimen Retention
# 590. Standard Guidance
# 591. Regulatory authority:10 NYCRR subdivision 58-1.2(c)
# 592. Document and Specimen Retention Standard of Practice 2 (DSR S2): Human Resources, Training and Competency Records
# 593. Document and Specimen Retention
# 594. Standard Guidance
# 595. Regulatory authority: 10 NYCRR Subdivision 58-1.2(d)
# 596. Document and Specimen Retention Standard of Practice 3 (DSR S3): Controlled Document Retention
# 597. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 598. Document and Specimen Retention
# 599. Standard Guidance
# 600. Document and Specimen Retention Standard of Practice 4 (DSR S4): Laboratory Information System Records Retention
# 601. Regulatory authority: 10 NYCRR subdivision 58-1.2(c)
# 602. Document and Specimen Retention Standard of Practice 5 (DSR S5): Verification Records
# 603. Regulatory authority: 10 NYCRR subdivision 58-1.10(g)
# 604. Document and Specimen Retention Standard of Practice 6 (DSR S6): Monitoring, Maintenance and Preventive Maintenance Records
# 605. Document and Specimen Retention
# 606. Standard Guidance
# 607. Regulatory authority: 10 NYCRR paragraphs 58- 1.11(c)(2),(3),(4)
# 608. Document and Specimen Retention Standard of Practice 7 (DSR S7): Test Request and Specimen Processing Documents
# 609. Document and Specimen Retention
# 610. Standard Guidance
# 611. Regulatory authority: 10 NYCRR paragraphs 58-1.11(c)(1) and (2)
# 612. Document and Specimen Retention Standard of Practice 8 (DSR S8): Analytic System Records Retention
# 613. Document and Specimen Retention
# 614. Standard Guidance
# 615. Regulatory authority: 10 NYCRR paragraphs 58- 1.11(c)(2),(3),(4)
# 616. Document and Specimen Retention Standard of Practice 9 (DSR S9): Report Retention
# 617. Regulatory authority: 10 NYCRR paragraph 58-1.11(c)(5)
# 618. Document and Specimen Retention
# 619. Standard Guidance
# 620. Document and Specimen Retention Standard of Practice 10 (DSR S10): Specimen Retention
# 621. Document and Specimen Retention
# 622. Standard Guidance
# 623. Regulatory authority: 10 NYCRR paragraph 58-1.11(d)(1)
# 624. Document and Specimen Retention Standard of Practice 11 (DSR S11): Proficiency Testing Records Retention
# 625. Document and Specimen Retention
# 626. Standard Guidance
# 627. Statutory authority: Article 5, Title 5 Public Health Law Section 576(3)
#
# 694. Regulatory authority: 10 NYCRR paragraph 19.3(c)(5) and subdivision 58-1.2(c)
# 695. Investigation and Corrective Action Standard of Practice 2 (ICA S2): Procedure and Documentation for Control of Nonconformities
# 696. Investigation and Corrective Action
# 697. Standard Guidance
# 698. Regulatory authority: 10 NYCRR paragraph 19.3(c)(5) and subdivision 58-1.2(c)
# 699. Investigation and Corrective Action Standard of Practice 3 (ICA S3): Actionable Events
# 700. Investigation and Corrective Action
# 701. Standard Guidance
# 702. Regulatory authority: 10 NYCRR paragraph 19.3(c)(5) and subdivision 58-1.2(c)
# 703. Investigation and Corrective Action Standard of Practice 4 (ICA S4): Corrective Action Procedure and Documentation
# 704. Investigation and Corrective Action
# 705. Standard Guidance
# 706. Regulatory authority: 10 NYCRR paragraph 19.3(c)(5) and subdivision 58-1.2(c)
# 707. Investigation and Corrective Action Standard of Practice 5 (ICA S5): Corrective Action Effectiveness
# 708. Regulatory authority: 10 NYCRR paragraph 19.3(c)(5) and subdivision 58-1.2(c)
# 709. APPENDIX
# 710. Table 1.
# 711. Section or Category Abbreviation Standard title
# 712. Table 2.
# 713. Section or Category Abbreviation Standard title
# 714. Section or Category Abbreviation Standard title

# %%
keywords = ["Quality Management System", "Standard", "Guidance", "Director Responsibilities", "Human Resources", "Facility Design", "Laboratory Safety", "Laboratory Safety" ]
my_list = bold_sentences

filtered_list = list(filter(lambda item: not any(keyword in item for keyword in keywords), my_list))
print(filtered_list)

# %%
import pdfplumber
import pandas as pd

pdf_path = "NYstandards.pdf"  # Replace with your actual PDF file path

# Initialize a list to store extracted tables
all_tables = []

# Open the PDF and extract tables
with pdfplumber.open(pdf_path) as pdf:
    for page_num, page in enumerate(pdf.pages, start=1):
        table = page.extract_table()  # Extract table from the page
        if table:
            df = pd.DataFrame(table)  # Convert table to DataFrame
            all_tables.append(df)  # Store in list

# Merge all tables into a single DataFrame
if all_tables:
    merged_df = pd.concat(all_tables, ignore_index=True)  # Merge and reset index
else:
    merged_df = pd.DataFrame()  # Create an empty DataFrame if no tables found

# Display the DataFrame
print(merged_df)
# Out:
#                                                      0  \
# 0
# 1                                             Standard
# 2    Quality Management System Fundamental Standard...
# 3
# 4                                             Standard
# ..                                                 ...
# 568    Oncology – Molecular and Cellular Tumor Markers
# 569                         Parentage/Identity Testing
# 570                                      Cytopathology
# 571                                     Histopathology
# 572                                     Trace Elements
#
#                              1         2       3     4     5  \
# 0    Quality Management System      None           NaN   NaN
# 1                         None  Guidance    None   NaN   NaN
# 2                         None              None   NaN   NaN
# 3    Quality Management System      None           NaN   NaN
# 4                         None  Guidance    None   NaN   NaN
# ..                         ...       ...     ...   ...   ...
# 568                       None      None   OC S2  None  None
# 569                       None      None  PIT S8  None  None
# 570                       None      None  CY S15  None  None
# 571                       None      None   HT S2  None  None
# 572                       None      None   TE S9  None  None
#
#                                                      6     7     8
# 0                                                  NaN   NaN   NaN
# 1                                                  NaN   NaN   NaN
# 2                                                  NaN   NaN   NaN
# 3                                                  NaN   NaN   NaN
# 4                                                  NaN   NaN   NaN
# ..                                                 ...   ...   ...
# 568  Molecular and Cellular Tumor Markers Report Re...  None  None
# 569                                     Report Content  None  None
# 570                                          Reporting  None  None
# 571                                Report Nomenclature  None  None
# 572                  Reporting Potential Contamination  None  None
#
# [573 rows x 9 columns]

# %%
merged_df.rename(columns={0: "Source", 1: "Description", 2: "Guidance"}, inplace=True)

# %%
merged_df.head()
# Out:
#                                               Source  \
# 0
# 1                                           Standard
# 2  Quality Management System Fundamental Standard...
# 3
# 4                                           Standard
#
#                  Description  Guidance     3    4    5    6    7    8  \
# 0  Quality Management System      None        NaN  NaN  NaN  NaN  NaN
# 1                       None  Guidance  None  NaN  NaN  NaN  NaN  NaN
# 2                       None            None  NaN  NaN  NaN  NaN  NaN
# 3  Quality Management System      None        NaN  NaN  NaN  NaN  NaN
# 4                       None  Guidance  None  NaN  NaN  NaN  NaN  NaN
#
#             Matched_Sentence  \
# 0
# 1                   Standard
# 2  Quality Management System
# 3
# 4                   Standard
#
#                                       Remaining_Text
# 0
# 1
# 2  Fundamental Standard of\nPractice (QMS FS)\nTh...
# 3
# 4

# %%
# Function to split text based on keyword match
def split_text_based_on_match(text, keyword_list):
    for keyword in keyword_list:
        if text.startswith(keyword):  # Check if text starts with the keyword
            return keyword, text[len(keyword):].strip()  # Split keyword from the rest
    return "", text  # If no match, leave first column empty and keep original text

# Apply function to split text into two columns
merged_df[["Matched_Sentence", "Remaining_Text"]] = merged_df["Source"].apply(
    lambda x: pd.Series(split_text_based_on_match(x, bold_sentences))
)

# Drop the original full text column (optional)
merged_df.drop(columns=["Source"], inplace=True)

# Print the modified DataFrame
print(merged_df)
# Out:
#                    Description  Guidance       3     4     5  \
# 0    Quality Management System      None           NaN   NaN
# 1                         None  Guidance    None   NaN   NaN
# 2                         None              None   NaN   NaN
# 3    Quality Management System      None           NaN   NaN
# 4                         None  Guidance    None   NaN   NaN
# ..                         ...       ...     ...   ...   ...
# 568                       None      None   OC S2  None  None
# 569                       None      None  PIT S8  None  None
# 570                       None      None  CY S15  None  None
# 571                       None      None   HT S2  None  None
# 572                       None      None   TE S9  None  None
#
#                                                      6     7     8  \
# 0                                                  NaN   NaN   NaN
# 1                                                  NaN   NaN   NaN
# 2                                                  NaN   NaN   NaN
# 3                                                  NaN   NaN   NaN
# 4                                                  NaN   NaN   NaN
# ..                                                 ...   ...   ...
# 568  Molecular and Cellular Tumor Markers Report Re...  None  None
# 569                                     Report Content  None  None
# 570                                          Reporting  None  None
# 571                                Report Nomenclature  None  None
# 572                  Reporting Potential Contamination  None  None
#
#               Matched_Sentence  \
# 0
# 1                     Standard
# 2    Quality Management System
# 3
# 4                     Standard
# ..                         ...
# 568
# 569
# 570
# 571
# 572
#
#                                         Remaining_Text
# 0
# 1
# 2    Fundamental Standard of\nPractice (QMS FS)\nTh...
# 3
# 4
# ..                                                 ...
# 568    Oncology – Molecular and Cellular Tumor Markers
# 569                         Parentage/Identity Testing
# 570                                      Cytopathology
# 571                                     Histopathology
# 572                                     Trace Elements
#
# [573 rows x 10 columns]

# %%
merged_df.to_csv("processed_sentences.csv", index=False)
