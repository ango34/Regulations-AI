# %%
from docx import Document

# Load the document
doc = Document("NYtables.docx")

for table_num, table in enumerate(doc.tables):
    print(f"Table {table_num + 1}:")  # Table numbering starts from 1

    for row in table.rows:
        row_text = [cell.text.strip() for cell in row.cells]  # Get text from each cell
        print("\t".join(row_text))  # Print tab-separated values for better formatting

    print("\n" + "-" * 50)  # Separator between tables
# Out:
# Table 1:
# Quality Management System
# Standard	Guidance
# Quality Management System Fundamental Standard of
# Practice (QMS FS)
# The laboratory must have a Quality Management System
# (QMS) that continuously assesses and improves the quality of
# laboratory services and ensures compliance with regulatory
# requirements. The laboratory director, and where appropriate,
# the owner, must be involved in designing and implementing the
# QMS.
# The QMS must:
# a) set quality goals, quality indicators, and performance
# expectations and/or thresholds;
# b) ensure quality goals are reviewed on a scheduled basis,
# and performance expectations are met;
# c) continuously monitor for deviations from quality goals or
# performance expectations;
# d) include scheduled system and process audits, at least
# annually; and
# e) have a system for correcting and documenting
# problems uncovered by monitoring or audits.
# Statutory authority: Article 5, Title 5 Public Health Law
# ...

# %%
from pdf2image import convert_from_path
import pytesseract
import os

# Define PDF path
pdf_path = "NYstandards.pdf"
poppler_path = r"C:\poppler-24.08.0\Library\bin"
# Convert PDF to images (one image per page)
images = convert_from_path(pdf_path, dpi=300, poppler_path=poppler_path)

# Loop through images and extract text
for i, image in enumerate(images):
    text = pytesseract.image_to_string(image, lang="eng")  # Adjust language if needed
    print(f"--- Page {i+1} ---\n{text}\n")

    # Optionally, save extracted text to a file
    with open(f"page_{i+1}.txt", "w", encoding="utf-8") as file:
        file.write(text)
# Out:
# --- Page 1 ---
# New York State Department of Health
# Wadsworth Center
#
# Clinical Laboratory Evaluation Program
#
# Clinical Laboratory Standards of Practice
#
# General Systems Standards
#
# Effective December 6, 2024
#
#
# --- Page 2 ---
# New York State Department of Health
# Clinical Laboratory Standards of Practice
# General Systems Standards
#
# Laboratories located in New York State, and laboratories conducting clinical or forensic testing on specimens originating in New York
# State regardless of location, must hold a New York State Department of Health clinical laboratory permit pursuant to Article 5, Title V,
# Section 574 of the New York State Public Health Law.
#
# All laboratories and blood banks holding a New York State clinical laboratory permit must adhere to applicable Clinical Laboratory
# Standards of Practice, including:
# e General Systems Standards; and
#
# e Specialty Requirements by Category.
#
# ...

# %%
import pdfplumber

pdf_path = "NYstandards.pdf"
text = ""

with pdfplumber.open(pdf_path) as pdf:
    for page in pdf.pages:
        text += page.extract_text() + "\n"

print(text)
# Out:
# New York State Department of Health
# Wadsworth Center
# Clinical Laboratory Evaluation Program
# Clinical Laboratory Standards of Practice
# General Systems Standards
# Effective December 6, 2024
# New York State Department of Health
# Clinical Laboratory Standards of Practice
# General Systems Standards
# Laboratories located in New York State, and laboratories conducting clinical or forensic testing on specimens originating in New York
# State regardless of location, must hold a New York State Department of Health clinical laboratory permit pursuant to Article 5, Title V,
# Section 574 of the New York State Public Health Law.
# All laboratories and blood banks holding a New York State clinical laboratory permit must adhere to applicable Clinical Laboratory
# Standards of Practice, including:
# • General Systems Standards; and
# • Specialty Requirements by Category.
# There are no category specific standards for the following permit categories:
# • Clinical Chemistry
# ...

# %%
import pdfplumber
import pandas as pd

# Path to the PDF file
pdf_path = "NYstandards.pdf"

# List to store extracted tables
tables_list = []

# Open the PDF and extract only tables
with pdfplumber.open(pdf_path) as pdf:
    for page_num, page in enumerate(pdf.pages):
        tables = page.extract_tables()
        
        for table_num, table in enumerate(tables):
            df = pd.DataFrame(table)
            tables_list.append(df)

# Combine all tables into a single DataFrame
if tables_list:
    final_df = pd.concat(tables_list, ignore_index=True)
    final_df.to_csv("tables_only.csv", index=False)
    print("Extracted tables saved to 'tables_only.csv'")
else:
    print("No tables found in the PDF.")
# Out:
# Tables with text saved to tables_output.csv
